# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pytesseract.pytesseract.tesseract_cmd =r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
import pytesseract
data = pytesseract.image_to_string('D:\\NLP_Cellula\\Task7\\part-two\\tests\\TS_myTearsRicochet.jpg')

# %%
data
# Out:
# 'my tears ricochet\nTaylor Swift\n\nAnd I can go anywhere |\nwant\n\nAnywhere | want, just not\nhome\n\nAnd you can aim for my\nheart, go for blood\n\nBut you would still miss me\nin your bones\n\nO seotity\n'
